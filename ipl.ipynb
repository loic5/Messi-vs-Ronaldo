# %%
from bs4 import BeautifulSoup
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
print("hello")
# Out:
# hello

# %%
url="https://www.sportskeeda.com/"
driver=webdriver.Chrome("C:/Program Files (x86)/chromedriver.exe")
driver.get(url)


#soup_level1=BeautifulSoup(driver.page_source, 'lxml')
#driver.quit()

# %%
py = driver.find_element_by_link_text("Cricket")
py.click()

# %%
s = driver.find_element_by_link_text("IPL 2020")
s.click()

# %%
sched=driver.find_element_by_link_text("Schedule")
sched.click()

# %%
soup_level1=BeautifulSoup(driver.page_source, 'lxml')

# %%
soup_level1
# Out:
# <html lang="en-us" style="min-height: 1213px;"><head>
# <!-- Google Tag Manager -->
# <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PZMZ8RP"></script><script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script>
# var gtmFired = false;
# document.addEventListener("mousemove", function() { loadGTM(); });
# document.addEventListener("scroll", function() { loadGTM(); });
# function loadGTM() {
# if(gtmFired) {
# return;
# }
# gtmFired = true;
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PZMZ8RP');
# }
# </script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="Indian Premier League 2020 - Get the IPL live scoreboard, ball by ball commentary, day to day results. Follow Sportskeeda for the latest Dream 11 IPL 2020 scores, today's IPL match score, updated results and highlights." name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="603431824" property="fb:admins"/>
# <meta content="1020623816" property="fb:admins"/>
# <meta content="394687130715834" property="fb:app_id"/>
# <!-- Begin new fb pages meta tags. -->
# <meta content="116151972998" property="fb:pages"/>
# <meta content="638392079590181" property="fb:pages"/>
# <meta content="1427355644210382" property="fb:pages"/>
# <meta content="1533778130171410" property="fb:pages"/>
# <meta content="353256696613" property="fb:pages"/>
# <meta content="233043350648" property="fb:pages"/>
# <meta content="189419887802605" property="fb:pages"/>
# <meta content="361214257357503" property="fb:pages"/>
# <meta content="161662747254143" property="fb:pages"/>
# <meta content="179374682137817" property="fb:pages"/>
# <meta content="671658282858797" property="fb:pages"/>
# <meta content="235149339867793" property="fb:pages"/>
# <meta content="113039892135516" property="fb:pages"/>
# <meta content="198888153532348" property="fb:pages"/>
# <meta content="480037188813382" property="fb:pages"/>
# <meta content="264363300269574" property="fb:pages"/>
# <meta content="1480789248868135" property="fb:pages"/>
# <meta content="229284143908" property="fb:pages"/>
# <meta content="664341660330270" property="fb:pages"/>
# <!-- End new fb pages meta tags. -->
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="notranslate" name="google"/>
# <meta content="jfoGxhn0lKDnzaezDsDeBPtaRA1TcLJHYpboESjADWw" name="google-site-verification"/>
# <meta content="5N5YyaIzynu432Je4SkbyXOd1iYd0O12aN24aLayocg" name="google-site-verification"/>
# <meta content="i2P5zopXY-X1BkOyPHr9Pq5JmDBZXpDYMWxRd8bSjHc" name="google-site-verification"/>
# <meta content="5Wtrqhwk1sAXs_fBPrS0wKXKuQlb-f76vbJtgT8IWkQ" name="google-site-verification"/>
# <meta content="HAvuvdUewFHQYRoif1w5BemTTsalBQatkd0wKlNTlSc" name="google-site-verification"/>
# <title>IPL Live Score - IPL 2020 Live Match Score, News, Live Commentary &amp; Results</title>
# <link href="https://plus.google.com/101781064736549245960/" rel="publisher"/>
# <link href="https://www.sportskeeda.com/favicon.ico" rel="shortcut" type="image/x-icon"/>
# <link href="https://staticg.sportskeeda.com/logo/sk-short-logo.png" rel="icon" sizes="192x192"/>
# <link href="https://staticg.sportskeeda.com/logo/sk-short-logo.png" rel="apple-touch-icon-precomposed" sizes="196x196"/>
# <link href="https://www.sportskeeda.com/amp/go/ipl" rel="amphtml"/>
# <link href="https://hindi.sportskeeda.com/go/ipl" hreflang="hi-in" rel="alternate"/>
# <link href="https://www.sportskeeda.com/go/ipl" hreflang="x-default" rel="alternate"/>
# <link href="https://www.sportskeeda.com/go/ipl" id="canonical-link" rel="canonical"/>
# <link href="https://www.sportskeeda.com/go/ipl?page=2" id="next-link" rel="next"/>
# <meta content="app" name="twitter:card"/>
# <meta content="India" name="twitter:app:country"/>
# <meta content="@sportskeeda" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://www.facebook.com/SportsKeeda" property="article:publisher"/>
# <link href="https://www.sportskeeda.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/apple-touch-icon-precomposed.png" rel="icon" type="image/png"/>
# <style>
# /* CSS reset */
# html, body, div, span, applet, object, iframe,
# h1, h2, h3, h4, h5, h6, p, blockquote, pre,
# a, abbr, acronym, address, big, cite, code,
# del, dfn, em, img, ins, kbd, q, s, samp,
# small, strike, strong, sub, sup, tt, var,
# b, u, i, center,
# dl, dt, dd, ol, ul, li,
# fieldset, form, label, legend,
# table, caption, tbody, tfoot, thead, tr, th, td,
# article, aside, canvas, details, embed,
# figure, figcaption, footer, header, hgroup,
# main, menu, nav, output, ruby, section, summary,
# time, mark, audio, video {
# margin: 0;
# padding: 0;
# border: 0;
# vertical-align: baseline;
# }
# iframe {
# position: relative;
# }
# /* HTML5 display-role reset for older browsers */
# article, aside, details, figcaption, figure,
# footer, header, hgroup, main, menu, nav, section {
# display: block;
# }
# body {
# line-height: 1;
# font-size:15px;
# }
# ol, ul {
# list-style: none;
# }
# blockquote, q {
# quotes: none;
# }
# blockquote:before, blockquote:after,
# q:before, q:after {
# content: '';
# content: none;
# }
# /* Don't kill focus outline for keyboard users */
# a:hover, a:active {
# outline: none;
# }
# table {
# border-collapse: collapse;
# border-spacing: 0;
# width: 100%!important;
# }
# /* Custom styles */
# *{
# box-sizing: border-box;
# }
# body{
# float: left;
# width: 100%;
# font-family: "Helvetica Neue", "Segoe UI", Helvetica, Arial, sans-serif;
# min-width:1200px;
# background:#f5f5f5;
# }
# .leaderadcont{
# width: 1200px;
# margin: 0 -50px;
# overflow: hidden;
# clear: both;
# z-index:1005;
# position:sticky;
# top: 20px;
# padding-top: 4px;
# background:#f6f6f6;
# }
# .editor-width-100-pc {
# margin-top:10px;
# }
# .bc-holder {
# z-index:3;
# }
# .container {
# width: 1100px;
# margin: 0 auto;
# overflow: hidden;
# line-height: 24px;
# clear:both;
# }
# .container p{ line-height: 24px; margin-bottom: 11px; font-size: 16px;float:left;width:100%;float:none; }
# h1{ font-size: 20px; line-height: 20px; margin: 30px 0 15px 0;float:left;  }
# .title{ color:#333; font-weight:300; width:100% }
# .subtitle{ font-weight: 100; color: #5F5F5F; font-size: 18px; line-height: 26px;margin-top: 10px; }
# .content-holder{ display: block;overflow: hidden; position: relative;}
# .content-holder figure{ width:100%; float: left;
# position:relative;
# }
# .content-holder img{ height: auto; max-width: 100%; background: #afafaf; color: #676767; margin: 0 auto; display: block; }
# .lazy-img{ max-width:100%!important; height:auto; }
# .content-holder figure img, .content-holder p img{ max-width: 100%; background: #afafaf; color: #afafaf;
# display:block }
# .content-holder p{ clear:both;width: 100%; padding: 0 24px; font-size: 18px !important; line-height: 35px; color:#222; background: transparent !important; }
# .event-content p{ font-size: 14px!important;}
# .content-holder a{ color:#0277BD; text-decoration: underline; }
# .content-holder table{ border: solid 1px #DEDEDE; overflow-x: auto; max-width:100%; }
# .content-holder table td, .content-holder table th{ margin: 0 auto;padding: 6px 7px; text-align: left;}
# .content-holder table tr{ border-bottom:solid 1px #DEDEDE; }
# .content-holder table tr:nth-of-type(odd){ background: #F7F7F7; }
# .content-holder table caption{ padding: 10px 0; color: #9E9E9E; }
# .half-width{ width:50%;float:left; }
# figcaption{ font-family: serif; font-style: italic; color: #777; font-size: 14px; padding: 7px 24px; text-align: center; }
# .section-heading{ font-weight: bold; color: #808080 !important; font-size: 16px; float: left; width: 100%;margin-bottom:10px }
# .transparent-button{ float: right; border-radius: 3px; box-shadow: #B1B1B1 1px 1px 4px; padding: 5px 10px; color: #000 !important;margin:3px 3px; background: white!important;text-decoration:none;cursor:pointer; }
# .transparent-button:hover{ background:#f7f7f7; text-decoration:underline; }
# .menu-container {
# overflow: visible;
# }
# .lazy{ max-height: 300px;background:#F7F7F7;max-width:100%; }
# .no-scroll{ overflow: hidden !important; max-height:auto !important; height:auto !important; }
# .lazy{ min-height: 50px; }
# .fr{ float:right; }
# .fl{ float:left; }
# td{ padding:5px;font-size: 14px; color: #333; }
# .cta-button-top{ font-size: 15px; margin-right: 10px; border: solid 1px #BD5454; border-radius: 3px; line-height: 14px; margin-top: 3px; }
# .cta-button-top:hover{ background:#BB2F2F }
# .show-more-button, .show-less-button{ margin-left: 10px; color: #2E87B5; cursor: pointer; text-decoration: underline;float:right }
# .submenu-right{ float:right;display:block;clear:none !important; }
# .submenu-right span{ color: #FFC6C6; font-size: 12px; margin: 3px 0 5px 10px; }
# .sharer{ margin-left: 18px; position: absolute; margin-top: 15px; border-radius: 3px; background: rgba(220, 220, 220, 0.28); overflow: hidden;height:26px;width:106px; }
# .sharer a{ width: 35px; text-align: center;height:26px }
# .sharer a:hover{ background:rgba(220, 220, 220, 0.28); }
# .fragments-container { float:left;width:740px;min-height:1px; }
# #keeda-profile-container{
# position: absolute;
# float: right;
# right: 0px;
# top: 17px;
# }
# #keeda-profile-container .toggle {
# width: 24px;
# height: 24px;
# margin: -3px 10px 0 20px;
# border-radius: 12px;
# }
# #main-menu{
# float: left;
# padding: 4px 6px;
# color: #d32f2f;
# font-weight: bold;
# cursor: pointer;
# height: 28px;
# margin: -5px 18px 18px 0;
# }
# #main-menu-text{
# display: inline-block; margin-right: 6px;
# }
# #main-menu:hover{
# background: #dcdcdc;
# }
# .no-select{
# -webkit-touch-callout: none;
# -webkit-user-select: none;
# -khtml-user-select: none;
# -moz-user-select: none;
# -ms-user-select: none;
# user-select: none;
# }
# #stories-list{
# background: #f5f5f5;
# }
# .desktop-bc-container{
# overflow:hidden;
# top: 0;
# line-height: 32px;
# }
# .hidden{
# display:none;
# }
# .homepage-logo{
# image-rendering: -moz-crisp-edges;
# image-rendering: -o-crisp-edges;
# image-rendering: -webkit-optimize-contrast;
# image-rendering: crisp-edges;
# -ms-interpolation-mode: nearest-neighbor;
# }
# .ad-container{
# padding:15px 0;
# float:left;
# clear:both;
# }
# .ad-container-leaderboard{
# padding:15px 0;
# clear:both;
# }
# .ad-declare-explicit{
# color: #808080;
# text-align: center;
# font-size: 10px;
# height:25px;
# }
# #kyc-below-floating-ad{
# float: left;
# clear: both;
# }
# blockquote {
# background-position: 0 0;
# display: block;
# font-weight: normal;
# font-family: Georgia, serif;
# background-repeat: no-repeat;
# margin: 1.5em 15px !important;
# line-height: 32px;
# color: #4c4c4c;
# font-size: 19px !important;
# border-radius: 6px;
# background-position-x: 10px;
# background: linear-gradient(45deg, #f3fff9, #abcae43d);
# padding: 17px 4px;
# }
# blockquote::first-letter {
# font-size: 180%;
# color: #57535a;
# }
# blockquote p {
# display: inline;
# }
# </style>
# <script>
# //Code is executed only on 1% of the pages
# if(Math.random() * 100 < 1) {
# window.SENTRY_SDK = {
# url: 'https://cdn.ravenjs.com/3.26.4/raven.min.js',
# dsn: 'https://e31f1e9e78bb4320beb2324075c1c6fc@sentry.io/106707',
# options: {
# release: '2019.07.30.2'
# }
# }
# //sentry-js script
# ;(function(a,b,g,e,h){var k=a.SENTRY_SDK,f=function(a){f.data.push(a)};f.data=[];var l=a[e];a[e]=function(c,b,e,d,h){f({e:[].slice.call(arguments)});l&&l.apply(a,arguments)};var m=a[h];a[h]=function(c){f({p:c.reason});m&&m.apply(a,arguments)};var n=b.getElementsByTagName(g)[0];b=b.createElement(g);b.src=k.url;b.crossorigin="anonymous";b.addEventListener("load",function(){try{a[e]=l;a[h]=m;var c=f.data,b=a.Raven;b.config(k.dsn,k.options).install();var g=a[e];if(c.length)for(var d=0;d<c.length;d++)c[d].e?g.apply(b.TraceKit,c[d].e):c[d].p&&b.captureException(c[d].p)}catch(p){console.log(p)}});n.parentNode.insertBefore(b,n)})(window,document,"script","onerror","onunhandledrejection");
# }
# </script>
# <script>
# function getCookie(cname) {
# var name = cname + "=";
# var ca = document.cookie.split(';');
# for(var i = 0; i < ca.length; i++) {
# var c = ca[i].trim();
# if (c.indexOf(name) === 0) {
# return c.substring(name.length,c.length).trim();
# }
# }
# return "";
# }
# function loadScriptAsync(scriptSrc, callback, attributes, DOMInto) {
# if (typeof callback !== 'function') {
# throw new Error('Not a valid callback for async script load');
# }
# var script = document.createElement('script');
# if(attributes && attributes.length > 0) {
# for(var attribIter = 0; attribIter < attributes.length; attribIter ++) {
# script.setAttribute(attributes[attribIter].attribKey, attributes[attribIter].attribValue);
# }
# }
# script.onload = callback;
# script.src = scriptSrc;
# if(DOMInto) {
# DOMInto.appendChild(script);
# } else {
# document.head.appendChild(script);
# }
# }
# var countryCode = getCookie("country_code").toLowerCase();
# if(countryCode == "us" || countryCode == "gb") {
# window.grumi = {
# key: '0210fb5d-3b9d-4da0-a61c-604f728ba4a6'
# };
# loadScriptAsync("//rumcdn.geoedge.be/0210fb5d-3b9d-4da0-a61c-604f728ba4a6/grumi-ip.js", function() { });
# }
# </script>
# <!--Query string init -->
# <script>
# var $ = document.querySelector.bind(document);
# var $all = document.querySelectorAll.bind(document);
# var GA_ID = 'UA-10769778-1';
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# googletag.cmd.push(function() {
# window && window.tercept && window.tercept.init && window.tercept.init(11446729);
# });
# </script>
# <!--GA tracking -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', GA_ID, 'auto');
# var isVideoPage = false;
# ga('send', 'event', 'page_type', 'Eventpage', document.location.href, { nonInteraction: true });
# ga('send', 'event', 'published_date', '', document.location.href, { nonInteraction: true });
# ga('send', 'event', 'debug_event', 'newlayout', document.location.href, { nonInteraction: true });
# ga('send', 'event', 'sport', 'Cricket', document.location.href, { nonInteraction: true });
# ga('set', 'dimension1', "Cricket");
# ga('set', 'dimension4', "false");
# if(!isVideoPage) {
# ga('send', 'pageview');
# }
# ga("send", "event", "sk_segment", getCookie("sk_segment"), "1", { nonInteraction: true });
# var getLocation = function(href) {
# var l = document.createElement("a");
# l.href = href;
# return l.pathname;
# };
# var besideH1Links = $all('ul.desktop-h1-side-menu li a')
# for(i=0; i< besideH1Links.length; i += 1) {
# var currentPath = document.location.pathname;
# if(currentPath === getLocation(besideH1Links[i].href)) {
# besideH1Links[i].className = besideH1Links[i].className + " active";
# }
# }
# </script>
# <script type="text/javascript">
# var gdprLoaded = false;
# var adopsdecisions = adopsdecisions || { };
# function loadGDPRStuff() {
# if(gdprLoaded) {
# return;
# }
# gdprLoaded = true;
# loadScriptAsync("https://cdn.cookielaw.org/opt-out/otCCPAiab.js", function() { }, [
# { "attribKey": "ccpa-opt-out-ids", "attribValue": "C0004" },
# { "attribKey": "charset", "attribValue": "UTF-8" },
# { "attribKey": "ccpa-opt-out-geo", "attribvalue": "all" },
# { "attribKey": "ccpa-opt-out-lspa", "attribValue": "true" }
# ]);
# loadScriptAsync("https://cdn.cookielaw.org/consent/tcf.stub.js", function() {
# __tcfapi('getTCData', 2, function (tcData, success) {
# if (success) {
# var consents = tcData.purpose.consents;
# if (consents['1'] && consents['3'] && consents['4']) {
# // serve personalized ads
# } else {
# googletag.cmd.push(function () {
# googletag.pubads().setRequestNonPersonalizedAds(1);
# });
# }
# } else {
# googletag.cmd.push(function () {
# googletag.pubads().setRequestNonPersonalizedAds(1);
# });
# }
# googletag.cmd.push(function(){
# googletag.pubads().refresh();
# });
# });
# }, [
# { "attribKey": "charset", "attribValue": "UTF-8" }
# ]);
# loadScriptAsync("https://cookie-cdn.cookiepro.com/scripttemplates/otSDKStub.js", function() { }, [
# { "attribKey": "charset", "attribValue": "UTF-8" },
# { "attribKey": "data-domain-script", "attribValue": "e237380e-6425-4ef4-b4fc-bdb0868df251-test"},
# ]);
# function OptanonWrapper() { }
# }
# if(getCookie("gdpr") == 'true') {
# loadGDPRStuff();
# adopsdecisions.gdprApplies = true;
# }
# googletag.cmd.push(function () {
# googletag.pubads().disableInitialLoad();
# });
# var GPTLoaded = false;
# var adQuickLoad = false;
# var nativeAdsDivsCreated =  true ;
# function loadGPT() {
# if(GPTLoaded) {
# return;
# }
# GPTLoaded = true;
# var gads = document.createElement('script');
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# gads.setAttribute('async', '');
# node.parentNode.insertBefore(gads, node);
# }
# var sessionKey1CookieVal = getCookie("sessionKey1");
# var firedPubTercept = false;
# if(location.search.indexOf("key1=opera") > -1 || location.search.indexOf("key1=mic") > -1 || sessionKey1CookieVal) {
# adQuickLoad = true;
# SKAdCall();
# }
# SKAdCall();
# if (!!document.referrer && !!document.referrer.match(/https:\/\/(.+?\.)?sportskeeda\.com\/$/gi) && !!location.href.match(/live-cricket-score/gi)) {
# SKAdCall(); // Load ad immmediatly for CMC if came from landing page
# }
# document.addEventListener("scroll", adInitOnInteraction);
# document.addEventListener("mousemove", adInitOnInteraction);
# function adInitOnInteraction() {
# SKAdCall();
# }
# var adUnits = JSON.parse('{"Desktop_300x600_Floating":{"div":"div-gpt-ad-1510306333397-0","mediaTypes":{"banner":{"sizes":[[160,600],[120,600]]}}},"Desktop_300x250_01_New":{"div":"div-gpt-ad-1510306106581-0","mediaTypes":{"banner":{"sizes":[[160,600],[120,600]]}}},"Desktop_300250_1":{"div":"div-gpt-ad-1471939034701-0","mediaTypes":{"banner":{"sizes":[[160,600],[120,600]]}}},"Desktop_300250_3":{"div":"div-gpt-ad-1589376019464-0","mediaTypes":{"banner":{"sizes":[[300,250],"fluid",[400,600],[400,280],[600,280],[500,280],[580,300],[580,400],[336,280],[480,320]]}}},"Desktop_300250_4":{"div":"div-gpt-ad-1471940214015-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Desktop_300250_5":{"div":"div-gpt-ad-1471940335856-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Desktop_72890_1":{"div":"div-gpt-ad-1471942863237-0","mediaTypes":{"banner":{"sizes":[[970,90],[728,90],[1200,90],[970,250]]}}},"Desktop_72890_2":{"div":"div-gpt-ad-1495182871411-0","mediaTypes":{"banner":{"sizes":[[728,90],[970,90]]}}},"Fluid_Native_Desktop":{"div":"div-gpt-ad-1557821524812-0","mediaTypes":{"banner":{"sizes":["fluid"]}},"native":true,"pos":3},"Fluid_Native_Desktop_2":{"div":"div-gpt-ad-1557821558584-0","mediaTypes":{"banner":{"sizes":["fluid"]}},"native":true,"pos":6},"Mob_32050_header":{"div":"div-gpt-ad-1472029132368-0","mediaTypes":{"banner":{"sizes":[[320,100],[300,100],[320,50],[300,50]]}}},"Mob_32050_Sticky_2019":{"div":"div-gpt-ad-1546862184774-0","mediaTypes":{"banner":{"sizes":[[300,50],[320,50],[320,100],[300,100]]}},"sticky":true},"CMC-Sticky":{"div":"div-gpt-ad-1597287049231-0","mediaTypes":{"banner":{"sizes":[[300,50],[320,100],[300,100],[320,50]]}},"sticky":true},"Mob_300250_1":{"div":"div-gpt-ad-1486709274862-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_2":{"div":"div-gpt-ad-1486709274862-1","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}},"parallax":true},"Mob_300250_3":{"div":"div-gpt-ad-1544790280952-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_4":{"div":"div-gpt-ad-1486709274862-3","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_5":{"div":"div-gpt-ad-1486709274862-4","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_6":{"div":"div-gpt-ad-1496133676474-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_08":{"div":"div-gpt-ad-1548079988588-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_09":{"div":"div-gpt-ad-1548079869235-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_10":{"div":"div-gpt-ad-1548079932983-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300250_11":{"div":"div-gpt-ad-1548080127306-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"MatchCenterHeader_300x50":{"div":"div-gpt-ad-1548933259437-0","mediaTypes":{"banner":{"sizes":[[300,50],[320,50],[300,100],[320,100]]}}},"MatchCenter_300x250_2019":{"div":"div-gpt-ad-1547097228479-0","mediaTypes":{"banner":{"sizes":[[300,50],[320,50],[300,100],[320,100]]}}},"MatchCenter_score_300x250_2019":{"div":"div-gpt-ad-1547540930933-0","mediaTypes":{"banner":{"sizes":[[300,50],[320,50],[300,100],[320,100],[300,250]]}}},"MatchPreviewHeader_2019":{"div":"div-gpt-ad-1549351402243-0","mediaTypes":{"banner":{"sizes":[[320,50],[300,50],[300,100],[320,100]]}}},"MatchPreview1_300x250_2019":{"div":"div-gpt-ad-1549351933760-0","mediaTypes":{"banner":{"sizes":[[300,250],[336,280],[250,250],[200,200],[250,200]]}}},"Mob_300100_TeamPage1":{"div":"div-gpt-ad-1553934815311-0","mediaTypes":{"banner":{"sizes":[[300,100],[300,50],[320,50],[ ...
# var nativeAds = [];
# function SKAdCall() {
# if(firedPubTercept) {
# return;
# }
# firedPubTercept = true;
# loadGPT();
# }
# function defineAndDisplayNativeAds(alreadyLoaded) {
# if(nativeAdsDivsCreated) {
# displayNativeAds(nativeAds)
# clearInterval(nativeAdsDivsCreatedInterval)
# }
# }
# function displayNativeAds(ads) {
# var stories = $all('.story-wrapper');
# ads.forEach(function(item, index) {
# if(stories[index]) {
# displayAdSlot(item.id);
# }
# });
# }
# function buildNativeAdSlots() {
# for (var adUnitKey in adUnits) {
# var slotIdWithCode = '/11446729/' + adUnitKey;
# if(adUnits[adUnitKey]['native']) {
# oneAd = new Array();
# oneAd['html'] = '<!-- '+slotIdWithCode+' --><div class="native-in-feed-ad hidden" id="'+adUnits[adUnitKey]['div']+'" style="overflow:hidden;height:130px;width:100%;clear:both;margin-bottom:20px;box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.07);"></div>';
# oneAd['id'] = adUnits[adUnitKey]['div'];
# nativeAds[adUnits[adUnitKey]['pos']] = oneAd;
# }
# }
# }
# buildNativeAdSlots()
# function spreadify (fn, fnThis) {
# return function (/* accepts unlimited arguments */) {
# var spreadArgs = [ ];
# var length = arguments.length;
# var currentArg;
# for (var i = 0; i < length; i++) {
# currentArg = arguments[i];
# if (Array.isArray(currentArg)) {
# spreadArgs = spreadArgs.concat(currentArg);
# } else {
# spreadArgs.push(currentArg);
# }
# }
# fn.apply(fnThis, spreadArgs);
# };
# }
# function defineAdSlot(slotId, optionalParams) {
# var divForAd = document.getElementById(adUnits[slotId]['div']);
# if(!divForAd && !adUnits[slotId]['native']) {
# return
# }
# if(adUnits[slotId] && adUnits[slotId]['defined']) {
# return;
# }
# adUnits[slotId]['defined'] = true;
# var sizes = adUnits[slotId]['mediaTypes']['banner']['sizes'];
# var slotIdWithCode = '/11446729/' + slotId;
# if(adUnits[slotId]['native']) {
# oneAd = new Array();
# oneAd['html'] = '<!-- '+slotIdWithCode+' --><div class="native-in-feed-ad hidden" id="'+adUnits[slotId]['div']+'" style="overflow:hidden;height:auto;min-height:130px;width:100%;clear:both;margin-bottom:20px;box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.07);"></div>';
# oneAd['id'] = adUnits[slotId]['div'];
# nativeAds[adUnits[slotId]['pos']] = oneAd;
# }
# if(optionalParams) {
# if(optionalParams['sizes']) {
# sizes = optionalParams['sizes'];
# }
# if(optionalParams['lazyLoadParams']) {
# var lzyLd = optionalParams['lazyLoadParams'];
# googletag.pubads().enableLazyLoad({
# fetchMarginPercent: lzyLd.fetchMarginPercent || 200,  // Fetch slots within fetchMarginPercent/100 viewports.
# renderMarginPercent: lzyLd.renderMarginPercent || 200,  // Render slots within renderMarginPercent/100 viewports.
# });
# }
# if(optionalParams['targeting']) {
# var targetedAdSlot = googletag.defineSlot(slotIdWithCode, sizes, adUnits[slotId]['div']).setTargeting(spreadify(optionalParams['targeting'])).addService(googletag.pubads());
# targetedAdSlot.setTargeting("version", "nopubmaticdesktop");
# return targetedAdSlot;
# }
# }
# var terceptIntegratedAdd = googletag.defineSlot(slotIdWithCode, sizes, adUnits[slotId]['div']).addService(googletag.pubads());;
# terceptIntegratedAdd.setTargeting("version", "nopubmaticdesktop");
# return terceptIntegratedAdd;
# }
# function displayAdSlot(divId) {
# googletag.cmd.push(function() { googletag.display(divId); });
# }
# function insertInfiniteContentAdSlot(slotId, adElement, device, adCounter) {
# if (!slotId) return;
# var slotIdWithCode = '/11446729/' + slotId;
# var sizes = adUnits[slotId]['mediaTypes']['banner']['sizes'];
# googletag.cmd.push(function() {
# var slot = googletag.defineSlot(slotIdWithCode, sizes)
# .setTargeting('recycle_count', adCounter) // where adCounter is count for the number of times this ad has been fetched till now, starting from 1
# .addService(googletag.pubads());
# var div = document.createElement('div');
# div.id = slot.getSlotElementId();
# if (device == 'mobile') {
# div.className = "mobile-ad-holder";
# }
# adElement.appendChild(div);
# console.log('DISPLAY ad : ', div.id);
# googletag.pubads().refresh([slot]);
# });
# return
# }
# googletag.cmd.push(function() {
# googletag.pubads().addEventListener("slotRenderEnded", function (e) {
# console.log( "ADSLOT Rendered – ", e.slot.getAdUnitPath(), e.slot.getSlotElementId());
# });
# });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# defineAdSlot('Desktop_72890_1');
# if(('Eventpage' === 'Eventpage') || 'Eventpage' === 'Sportspage' || 'Eventpage' === 'ATRPage'){
# defineAdSlot('Fluid_Native_Desktop');
# defineAdSlot('Fluid_Native_Desktop_2');
# if((("Cricket" === "Cricket") || ("Cricket" === "Football") || ("Cricket" === "Kabaddi"))){
# defineAdSlot('Desktop_300x250_01_New');
# defineAdSlot('Desktop_300250_1');
# defineAdSlot('Desktop_300x600_Floating');
# } else {
# defineAdSlot('Desktop_300250_1');
# defineAdSlot('Desktop_300x600_Floating', { 'sizes': [[160, 600], [300, 600]]});
# }
# }
# if(("Eventpage" === 'teampage') || ("Eventpage" === 'playerpage') || ("Eventpage" === 'Tagpage') || ("Eventpage" === 'AuthorProfilePage')){
# defineAdSlot('Desktop_300250_1');
# }
# googletag.defineOutOfPageSlot('/11446729/Interstitial', 'div-gpt-ad-1423053234910-0').addService(googletag.pubads());
# googletag.pubads().addEventListener('slotRenderEnded', function(e) {
# if (e.isEmpty) {
# return;
# }
# if (e.slot.getSlotElementId() === "div-gpt-ad-1546862184774-0" || e.slot.getSlotElementId() === "div-gpt-ad-1597287049231-0") {
# var adHeight = e.size[1];
# $(".sticky-container").style.height = (adHeight + 5) + "px";
# $(".sticky-close").style.bottom = (adHeight + 4) + "px";
# var sticky_close = $('.sticky-close');
# sticky_close.addEventListener('click', function(el) {
# addClass(el.target.parentElement, 'hidden');
# refreshMSticky = false;
# });
# removeClass(sticky_close, 'hidden');
# addClass($('.sticky-container'), 'sticky-container-box');
# }
# if (e.slot.getSlotElementId() === "div-gpt-ad-1562932228734-0") {
# removeClass($('.sk-logo-skip'), 'hidden');
# removeClass($('.interstitial-fullpage'), 'hidden');
# var interstitial_timer = setInterval(function(){
# skipAd();
# clearInterval(interstitial_timer);
# },10000);
# setAdDisplayed();
# }
# if (e.slot.getSlotElementId() === "div-gpt-ad-1589376019464-0") {
# var adHeight = e.size[1];
# $('#div-gpt-ad-1589376019464-0').parentElement.style.minHeight = adHeight + 24 + 'px';
# }
# var cubeExpandoCreativeIDs = [138230072083, 138232852373, 138233359402, 138234976177, 138235557507, 138249246421, 138250001051, 138250349254, 138251570439, 138273000453];
# if(cubeExpandoCreativeIDs.indexOf(e.creativeId) > -1){
# var desktopNativeIframe1 = document.getElementById('google_ads_iframe_/11446729/Desktop_300x250_01_New_0');
# desktopNativeIframe1.addEventListener('mouseover', function(){
# if(desktopNativeIframe1){
# desktopNativeIframe1.style.height = '500px';
# desktopNativeIframe1.style.width = '700px';
# desktopNativeIframe1.style.left = '-200px';
# desktopNativeIframe1.style.zIndex = '1000';
# }
# });
# desktopNativeIframe1.contentDocument.addEventListener('click', function(){
# desktopNativeIframe1.style.height = '250px';
# desktopNativeIframe1.style.width = '300px';
# desktopNativeIframe1.style.left = '0px';
# });
# }
# //manually expand iframes for fluid native mobile and desktop ads
# var iFrames = [];
# iFrames.push(document.getElementById('google_ads_iframe_/11446729/Fluid_Native_Desktop_0'));
# iFrames.push(document.getElementById('google_ads_iframe_/11446729/Fluid_Native_Desktop_2_0'));
# for(var i = 0; i < iFrames.length; i++) {
# if(iFrames[i]) {
# iFrames[i].style.height = 'auto';
# }
# }
# var nativeAdsVisible = $all(".native-in-feed-ad");
# for(var i=0; i < nativeAdsVisible.length; i++) {
# removeClass(nativeAdsVisible[i], "hidden");
# }
# var creativeIdsToExclude = [138286151923,138285840245,138271731634,138268373199,138285082925,138271730923,138286887039,138286887168,138287419347,138287833123,138287833285,138287419728,138287420292,138287524349,138289266024,138289265892,138289283295,138289282086,138275980931,138291182180,138292966902,138244994872,138294681725,138294843218,138294825591,138268666069,138295315372,138295315249,138294999918,138295316080,138295001034,138295000692,138295890736,138265303851,138281235704,138305743306,138306859562,138308272356,138239628002,138313660868];
# if(creativeIdsToExclude.indexOf(e.creativeId) > -1) {
# // This is a creative that is not controlled by SK, and need not be expanded
# return;
# }
# });
# function hideInterstitialIFrame() {
# var desktopInterstitialAdDiv = document.getElementById('div-gpt-ad-1423053234910-0');
# if (desktopInterstitialAdDiv) {
# desktopInterstitialAdDiv.style.display = 'none';
# }
# var mobileInterstitialAdDiv = document.getElementById('div-gpt-ad-1426841729957-0');
# if (mobileInterstitialAdDiv) {
# mobileInterstitialAdDiv.style.display = 'none';
# }
# }
# window.onmessage = function (e) {
# if (e.data == 'adCloseEvent') {
# hideInterstitialIFrame()
# } else if (e.data == 'MOBILE_INTERSTITIAL_AD_LOADED' || e.data == 'DESKTOP_INTERSTITIAL_AD_LOADED') {
# var interstitialIframe = null;
# if (e.data == 'DESKTOP_INTERSTITIAL_AD_LOADED') {
# interstitialIframe = document.getElementById('google_ads_iframe_/11446729/Interstitial_0');
# } else if (e.data == 'MOBILE_INTERSTITIAL_AD_LOADED') {
# interstitialIframe = document.getElementById('google_ads_iframe_/11446729/Mobileinterstitial_0');
# } else {
# return;
# }
# interstitialIframe.style.width = '100%';
# interstitialIframe.style.height = '1000px';
# interstitialIframe.style.position = 'fixed';
# interstitialIframe.style.zIndex = '10000';
# interstitialIframe.style.left = '0';
# interstitialIframe.style.top = '0';
# interstitialIframe.contentDocument.addEventListener('click', hideInterstitialIFrame);
# }
# };
# googletag.pubads().setTargeting("url", document.location.protocol + "//" + document.location.hostname + document.location.pathname);
# googletag.pubads().setTargeting("pagetype", "Eventpage");
# googletag.pubads().setTargeting("sport", "Cricket");
# googletag.pubads().setTargeting("event", "ipl");
# googletag.pubads().setTargeting("lang", "en");
# var landingPage = document.referrer.match(/https:\/\/[a-z]*.sportskeeda.com/) ? "false" : "true"
# googletag.pubads().setTargeting("landing_page", landingPage);
# var queryParams = document.location.search.replace('?', "").split('&');
# for (var i = 0; i < queryParams.length; i += 1) {
# var keyValuePair = queryParams[i].split('=');
# var key = keyValuePair[0];
# if(key === "key1" && keyValuePair[1]) {
# var value = keyValuePair[1];
# googletag.pubads().setTargeting(key, value);
# document.addEventListener("click", function(e) {
# var targetNode = e.target;
# while(!targetNode.href && targetNode.parentNode) {
# targetNode = targetNode.parentNode;
# }
# if(targetNode.href) {
# e.preventDefault();
# var urlToNavigateTo = new URL(targetNode.href);
# if(urlToNavigateTo.search) { //already has a query String
# targetNode.href += '&key1=' + value;
# } else {
# targetNode.href += '?key1=' + value;
# }
# window.location = targetNode.href;
# }
# });
# } else if(key === "key2" && keyValuePair[1]) {
# var value = keyValuePair[1];
# googletag.pubads().setTargeting(key, value);
# } else {
# var sessionKey1CookieVal = getCookie("sessionKey1");
# if(sessionKey1CookieVal) {
# googletag.pubads().setTargeting("key1", sessionKey1CookieVal);
# }
# }
# }
# googletag.pubads().enableSingleRequest();
# googletag.pubads().collapseEmptyDivs();
# googletag.enableServices();
# });
# if(!adopsdecisions.gdprApplies) {
# googletag.cmd.push(function(){
# googletag.pubads().refresh();
# });
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/kings-xi-punjab-vs-kolkata-knight-riders-24th-match-10-october-2020",
# "name": "Kings XI Punjab vs Kolkata Knight Riders",
# "description": "IPL 2020",
# "startDate": "2020-10-10T10:00:00+00:00+05:30",
# "endDate": "2020-10-11T03:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Kings XI Punjab",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kings-xi-punjab.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kolkata Knight Riders",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kolkata-knight-riders.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sheikh Zayed Stadium, Abu Dhabi, Abu Dhabi"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/chennai-super-kings-vs-royal-challengers-bangalore-25th-match-10-october-2020",
# "name": "Chennai Super Kings vs Royal Challengers Bangalore",
# "description": "IPL 2020",
# "startDate": "2020-10-10T14:00:00+00:00+05:30",
# "endDate": "2020-10-11T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Chennai Super Kings",
# "image": "https://staticg.sportskeeda.com/cricket_widget/chennai-super-kings.png"
# }, {
# "@type": "SportsTeam",
# "name": "Royal Challengers Bangalore",
# "image": "https://staticg.sportskeeda.com/cricket_widget/royal-challengers-bangalore.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/sunrisers-hyderabad-vs-rajasthan-royals-26th-match-11-october-2020",
# "name": "Sunrisers Hyderabad vs Rajasthan Royals",
# "description": "IPL 2020",
# "startDate": "2020-10-11T10:00:00+00:00+05:30",
# "endDate": "2020-10-12T03:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Sunrisers Hyderabad",
# "image": "https://staticg.sportskeeda.com/cricket_widget/sunrisers-hyderabad.png"
# }, {
# "@type": "SportsTeam",
# "name": "Rajasthan Royals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/rajasthan-royals.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/mumbai-indians-vs-delhi-capitals-27th-match-11-october-2020",
# "name": "Mumbai Indians vs Delhi Capitals",
# "description": "IPL 2020",
# "startDate": "2020-10-11T14:00:00+00:00+05:30",
# "endDate": "2020-10-12T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Mumbai Indians",
# "image": "https://staticg.sportskeeda.com/cricket_widget/mumbai-indians.png"
# }, {
# "@type": "SportsTeam",
# "name": "Delhi Capitals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/delhi-daredevils.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sheikh Zayed Stadium, Abu Dhabi, Abu Dhabi"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/royal-challengers-bangalore-vs-kolkata-knight-riders-28th-match-12-october-2020",
# "name": "Royal Challengers Bangalore vs Kolkata Knight Riders",
# "description": "IPL 2020",
# "startDate": "2020-10-12T14:00:00+00:00+05:30",
# "endDate": "2020-10-13T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Royal Challengers Bangalore",
# "image": "https://staticg.sportskeeda.com/cricket_widget/royal-challengers-bangalore.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kolkata Knight Riders",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kolkata-knight-riders.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sharjah Cricket Stadium, Sharjah"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/sunrisers-hyderabad-vs-chennai-super-kings-29th-match-13-october-2020",
# "name": "Sunrisers Hyderabad vs Chennai Super Kings",
# "description": "IPL 2020",
# "startDate": "2020-10-13T14:00:00+00:00+05:30",
# "endDate": "2020-10-14T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Sunrisers Hyderabad",
# "image": "https://staticg.sportskeeda.com/cricket_widget/sunrisers-hyderabad.png"
# }, {
# "@type": "SportsTeam",
# "name": "Chennai Super Kings",
# "image": "https://staticg.sportskeeda.com/cricket_widget/chennai-super-kings.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/delhi-capitals-vs-rajasthan-royals-30th-match-14-october-2020",
# "name": "Delhi Capitals vs Rajasthan Royals",
# "description": "IPL 2020",
# "startDate": "2020-10-14T14:00:00+00:00+05:30",
# "endDate": "2020-10-15T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Delhi Capitals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/delhi-daredevils.png"
# }, {
# "@type": "SportsTeam",
# "name": "Rajasthan Royals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/rajasthan-royals.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/royal-challengers-bangalore-vs-kings-xi-punjab-31st-match-15-october-2020",
# "name": "Royal Challengers Bangalore vs Kings XI Punjab",
# "description": "IPL 2020",
# "startDate": "2020-10-15T14:00:00+00:00+05:30",
# "endDate": "2020-10-16T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Royal Challengers Bangalore",
# "image": "https://staticg.sportskeeda.com/cricket_widget/royal-challengers-bangalore.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kings XI Punjab",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kings-xi-punjab.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sharjah Cricket Stadium, Sharjah"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/mumbai-indians-vs-kolkata-knight-riders-32nd-match-16-october-2020",
# "name": "Mumbai Indians vs Kolkata Knight Riders",
# "description": "IPL 2020",
# "startDate": "2020-10-16T14:00:00+00:00+05:30",
# "endDate": "2020-10-17T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Mumbai Indians",
# "image": "https://staticg.sportskeeda.com/cricket_widget/mumbai-indians.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kolkata Knight Riders",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kolkata-knight-riders.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sheikh Zayed Stadium, Abu Dhabi, Abu Dhabi"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/rajasthan-royals-vs-royal-challengers-bangalore-33rd-match-17-october-2020",
# "name": "Rajasthan Royals vs Royal Challengers Bangalore",
# "description": "IPL 2020",
# "startDate": "2020-10-17T10:00:00+00:00+05:30",
# "endDate": "2020-10-18T03:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Rajasthan Royals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/rajasthan-royals.png"
# }, {
# "@type": "SportsTeam",
# "name": "Royal Challengers Bangalore",
# "image": "https://staticg.sportskeeda.com/cricket_widget/royal-challengers-bangalore.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/delhi-capitals-vs-chennai-super-kings-34th-match-17-october-2020",
# "name": "Delhi Capitals vs Chennai Super Kings",
# "description": "IPL 2020",
# "startDate": "2020-10-17T14:00:00+00:00+05:30",
# "endDate": "2020-10-18T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Delhi Capitals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/delhi-daredevils.png"
# }, {
# "@type": "SportsTeam",
# "name": "Chennai Super Kings",
# "image": "https://staticg.sportskeeda.com/cricket_widget/chennai-super-kings.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sharjah Cricket Stadium, Sharjah"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/sunrisers-hyderabad-vs-kolkata-knight-riders-35th-match-18-october-2020",
# "name": "Sunrisers Hyderabad vs Kolkata Knight Riders",
# "description": "IPL 2020",
# "startDate": "2020-10-18T10:00:00+00:00+05:30",
# "endDate": "2020-10-19T03:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Sunrisers Hyderabad",
# "image": "https://staticg.sportskeeda.com/cricket_widget/sunrisers-hyderabad.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kolkata Knight Riders",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kolkata-knight-riders.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sheikh Zayed Stadium, Abu Dhabi, Abu Dhabi"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/mumbai-indians-vs-kings-xi-punjab-36th-match-18-october-2020",
# "name": "Mumbai Indians vs Kings XI Punjab",
# "description": "IPL 2020",
# "startDate": "2020-10-18T14:00:00+00:00+05:30",
# "endDate": "2020-10-19T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Mumbai Indians",
# "image": "https://staticg.sportskeeda.com/cricket_widget/mumbai-indians.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kings XI Punjab",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kings-xi-punjab.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/rajasthan-royals-vs-chennai-super-kings-37th-match-19-october-2020",
# "name": "Rajasthan Royals vs Chennai Super Kings",
# "description": "IPL 2020",
# "startDate": "2020-10-19T14:00:00+00:00+05:30",
# "endDate": "2020-10-20T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Rajasthan Royals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/rajasthan-royals.png"
# }, {
# "@type": "SportsTeam",
# "name": "Chennai Super Kings",
# "image": "https://staticg.sportskeeda.com/cricket_widget/chennai-super-kings.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sheikh Zayed Stadium, Abu Dhabi, Abu Dhabi"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/kings-xi-punjab-vs-delhi-capitals-38th-match-20-october-2020",
# "name": "Kings XI Punjab vs Delhi Capitals",
# "description": "IPL 2020",
# "startDate": "2020-10-20T14:00:00+00:00+05:30",
# "endDate": "2020-10-21T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Kings XI Punjab",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kings-xi-punjab.png"
# }, {
# "@type": "SportsTeam",
# "name": "Delhi Capitals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/delhi-daredevils.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/royal-challengers-bangalore-vs-kolkata-knight-riders-39th-match-21-october-2020",
# "name": "Royal Challengers Bangalore vs Kolkata Knight Riders",
# "description": "IPL 2020",
# "startDate": "2020-10-21T14:00:00+00:00+05:30",
# "endDate": "2020-10-22T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Royal Challengers Bangalore",
# "image": "https://staticg.sportskeeda.com/cricket_widget/royal-challengers-bangalore.png"
# }, {
# "@type": "SportsTeam",
# "name": "Kolkata Knight Riders",
# "image": "https://staticg.sportskeeda.com/cricket_widget/kolkata-knight-riders.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sheikh Zayed Stadium, Abu Dhabi, Abu Dhabi"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/rajasthan-royals-vs-sunrisers-hyderabad-40th-match-22-october-2020",
# "name": "Rajasthan Royals vs Sunrisers Hyderabad",
# "description": "IPL 2020",
# "startDate": "2020-10-22T14:00:00+00:00+05:30",
# "endDate": "2020-10-23T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Rajasthan Royals",
# "image": "https://staticg.sportskeeda.com/cricket_widget/rajasthan-royals.png"
# }, {
# "@type": "SportsTeam",
# "name": "Sunrisers Hyderabad",
# "image": "https://staticg.sportskeeda.com/cricket_widget/sunrisers-hyderabad.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Dubai International Cricket Stadium, Dubai"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/chennai-super-kings-vs-mumbai-indians-41st-match-23-october-2020",
# "name": "Chennai Super Kings vs Mumbai Indians",
# "description": "IPL 2020",
# "startDate": "2020-10-23T14:00:00+00:00+05:30",
# "endDate": "2020-10-24T07:30:00+05:30",
# "competitor": [{
# "@type": "SportsTeam",
# "name": "Chennai Super Kings",
# "image": "https://staticg.sportskeeda.com/cricket_widget/chennai-super-kings.png"
# }, {
# "@type": "SportsTeam",
# "name": "Mumbai Indians",
# "image": "https://staticg.sportskeeda.com/cricket_widget/mumbai-indians.png"
# }],
# "location": {
# "@type": "Place",
# "address": {
# "@type": "PostalAddress",
# "name": "Sharjah Cricket Stadium, Sharjah"
# }
# }
# }
# </script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "SportsEvent",
# "url" : "https://www.sportskeeda.com/live-cricket-score/kolkata-knight-riders-vs-delhi-capitals-42nd-match-24-october-2020",
# ...
# termTaxonomyId : parseInt(unfavoritedElement.dataset.termTaxonomyId),
# title : unfavoritedElement.dataset.title,
# image_url : unfavoritedElement.dataset.image_url,
# url: unfavoritedElement.dataset.url,
# taxonomy: unfavoritedElement.dataset.taxonomy,
# slug: unfavoritedElement.dataset.slug,
# menu_name: unfavoritedElement.dataset.menu_name,
# default: unfavoritedElement.dataset.default
# };
# favoriteChoicesListBlock.append(createFavoriteChoices(choice, 'favorite'));
# popularListBlock.append(createFavoriteChoices(choice, 'popular'));
# }
# saveUserFavorites(userFavoritedTaxonomies);
# unfavoritedElement.parentNode.removeChild(unfavoritedElement);
# ga('send', 'event', 'REMOVE_FAVORITE', 'MENU_CHOICE',unfavoritedElement.dataset.slug, { nonInteraction: true });
# }
# function onEditFavoritesClicked(event) {
# var favoritesList = favoritesListBlock.querySelectorAll('.favorite-block');
# editModeActive = false;
# if(!hasClass(favoritesElement, 'edit-mode')) {
# addClass(favoritesElement, 'edit-mode');
# editModeActive = true;
# } else {
# removeClass(favoritesElement, 'edit-mode');
# }
# for (var i = 0; i < favoritesList.length; i++) {
# if(!hasClass(favoritesList[i], 'edit')) {
# addClass(favoritesList[i], 'edit');
# } else {
# removeClass(favoritesList[i], 'edit');
# }
# }
# if (favoritesSearchInput.value != "" && typeof(ga) !== "undefined") {
# ga('send', 'event', 'FAV_SEARCH', 'EDIT', favoritesSearchInput.value, { nonInteraction: true });
# }
# favoritesSearchInput.value = "";
# addClass(searchResultsContainer, "hidden");
# removeClass(favoritesSearchDismiss, "active");
# if(editModeActive) {
# addClass(sideBarMenu, 'edit-mode');
# removeClass($(".favorites-edit"), 'hidden');
# addClass($(".favorites .fav-header"), 'hidden');
# addClass(favoritesSearch, 'active');
# addClass(globalMenuElement, 'hidden');
# addClass(popularListElement, 'hidden');
# addClass(favoriteChoicesElement, 'active');
# addClass(kycElement, 'hidden');
# favoritesSearch.setAttribute('style','padding-top:0px');
# favoritesSearchInput.focus();
# ga('send', 'event', 'MENU_EDIT_CLICK', { nonInteraction: true });
# } else {
# removeClass(sideBarMenu, 'edit-mode');
# removeClass(favoritesListBlock, 'hidden');
# removeClass($(".favorites .fav-header"), 'hidden');
# addClass($(".favorites-edit"), 'hidden');
# removeClass(favoritesSearch, 'active');
# removeClass(globalMenuElement, 'hidden');
# removeClass(popularListElement, 'hidden');
# removeClass(favoriteChoicesElement, 'active');
# removeClass(kycElement, 'hidden');
# favoritesSearch.setAttribute('style','padding-top:12px');
# }
# }
# function onSeeMoreClicked(event) {
# seeMoreBlock.style.display = "none";
# if(!hasClass(globalListBlock, 'full-menu')) {
# addClass(globalListBlock, 'full-menu');
# }
# }
# function onNavExpandClicked() {
# var subMenu = this.parentNode.querySelector('.submenu');
# if(!hasClass(subMenu, 'open')) {
# addClass(subMenu, 'open');
# } else {
# removeClass(subMenu, 'open');
# }
# }
# function closeOtherMenu(ths){
# var node = ths.parentNode.firstChild;
# var height = 0;
# var flag = true;
# var scrollTop = $('.keeda-side-menu').scrollTop;
# while (node) {
# if (node.nodeType === Node.ELEMENT_NODE && node !== ths) {
# var openNodes = node.querySelectorAll(".open");
# if (openNodes.length) {
# for (i = 0; i < openNodes.length; i++) {
# if (height == 0 && flag) {
# height = height + openNodes[i].getBoundingClientRect().height;
# }
# removeClass(openNodes[i], 'open');
# }
# }
# var arrowUpNodes = node.querySelectorAll(".arrow-up");
# if (arrowUpNodes.length) {
# for (i = 0; i < arrowUpNodes.length; i++) {
# removeClass(arrowUpNodes[i], 'arrow-up');
# arrowUpNodes[i].style.backgroundImage="url('https://staticg.sportskeeda.com/skm/assets/menu/arrow-down.svg')";
# }
# }
# }
# if (node.nodeType === Node.ELEMENT_NODE && node == ths) {
# flag = false;
# }
# node = node.nextElementSibling || node.nextSibling;
# }
# $('.keeda-side-menu').scrollTop = scrollTop - height;
# }
# function onNavExpandSportClicked(event) {
# var menu = $('#sport-expander').parentNode.parentNode.querySelector('.list');
# var navArrow = $('#sport-expander');
# if(!hasClass(menu, 'open')) {
# addClass(menu, 'open');
# addClass(navArrow, 'arrow-up');
# removeClass(globalMenuElement, 'collapsed');
# navArrow.style.backgroundImage="url('https://staticg.sportskeeda.com/skm/assets/menu/arrow-up.svg')";
# } else {
# removeClass(menu, 'open');
# removeClass(navArrow, 'arrow-up');
# addClass(globalMenuElement, 'collapsed');
# navArrow.style.backgroundImage="url('https://staticg.sportskeeda.com/skm/assets/menu/arrow-down.svg')";
# }
# }
# function onNavExpandArrowClicked(event) {
# var subMenu = event.target.parentNode.querySelector('.submenu');
# var navArrow = event.target;
# if(!hasClass(subMenu, 'open')) {
# closeOtherMenu(event.target.parentNode);
# addClass(subMenu, 'open');
# addClass(navArrow, 'arrow-up');
# event.target.style.backgroundImage="url('https://staticg.sportskeeda.com/skm/assets/menu/arrow-up.svg')";
# } else {
# removeClass(subMenu, 'open');
# removeClass(navArrow, 'arrow-up');
# event.target.style.backgroundImage="url('https://staticg.sportskeeda.com/skm/assets/menu/arrow-down.svg')";
# }
# }
# var backspaceFlag = 0;
# var preVal = ""
# function onFavoritesSearchInput(event) {
# var searchInputElement = event.target;
# var searchKeyword = searchInputElement.value;
# addClass(favoritesSearchDismiss, 'active');
# removeClass(searchResultsContainer, "hidden");
# if (event.keyCode == 8 || event.keyCode == 27) {
# if (backspaceFlag == 0) {
# ga('send', 'event', 'FAV_SEARCH', 'BACK', preVal, { nonInteraction: true });
# backspaceFlag = 1;
# }
# } else {
# backspaceFlag = 0;
# }
# if(searchKeyword === "" || event.keyCode === 27) {
# searchInputElement.value = "";
# if(hasClass(globalMenuElement, 'hidden')) {
# addClass(favoriteChoicesElement, 'active');
# }
# removeClass(favoritesListBlock, 'hidden');
# addClass($('.no-result-message'), 'hidden');
# clearSearchResults();
# } else {
# if(hasClass(globalMenuElement, 'hidden')) {
# removeClass(favoriteChoicesElement, 'active');
# addClass(favoritesListBlock, 'hidden');
# }
# addClass($('.no-result-message'), 'hidden');
# //Here we are replacing the invalid characters with the white-space
# searchKeyword = searchKeyword.replace(/[|&;\'$%@#*"=+{}<>.?^:/~!\"<>+,\\\[\]\(\)\-\_]/g, " ");
# searchKeyword = searchKeyword.substring(0,100);
# searchInputElement.value = searchKeyword;
# searchForFavorites(searchKeyword)
# .then(function(results) {
# loadSearchResults(results);
# })
# .catch(function(err) {
# });
# }
# preVal = searchInputElement.value;
# }
# function onSeachDismissClicked(event, noFocus) {
# var searchInputElement = $(".search-container").querySelector('input');
# if(typeof(ga) !== "undefined") {
# ga('send', 'event', 'FAV_SEARCH', 'DISMISS', searchInputElement.value, { nonInteraction: true });
# }
# searchInputElement.value = "";
# if(hasClass(globalMenuElement, 'hidden')) {
# addClass(favoriteChoicesElement, 'active');
# }
# removeClass(favoritesSearchDismiss, 'active');
# removeClass(favoritesListBlock, 'hidden');
# addClass($('.no-result-message'), 'hidden');
# clearSearchResults();
# if(!noFocus) {
# favoritesSearchInput.focus();
# }
# }
# var isMenuOpenDefault = 0;
# function onMenuClicked(event) {
# onSeachDismissClicked(event, noFocus = true);
# populateFavorites();
# if(hasClass(sideBarMenu, 'open')) {
# removeClass(sideBarMenu, 'open');
# sideBarOpen = false;
# } else {
# addClass(sideBarMenu, 'open');
# sideBarOpen = true;
# }
# var containerElements = $all('.container');
# var fragmentsContainer = $('.fragments-container');
# if(sideBarOpen) {
# addClass(mobileOverlay, 'active');
# addClass($("body"), 'sidebarActive');
# for (var i = 0; i < containerElements.length; i++) {
# addClass(containerElements[i], 'menu-open');
# }
# addClass(fragmentsContainer,'menu-open');
# if (isMenuOpenDefault == 0 && typeof(ga) !== "undefined") {
# ga('send', 'event', 'MENU_CLICK', { nonInteraction: true });
# }
# resizeHandleForLogo();
# } else {
# removeClass(mobileOverlay, 'active');
# removeClass($("body"), 'sidebarActive');
# for (var i = 0; i < containerElements.length; i++) {
# removeClass(containerElements[i], 'menu-open');
# }
# removeClass(fragmentsContainer,'menu-open');
# if($('.homepage-logo')) {
# $('.homepage-logo').style.transition = "all 0.2s cubic-bezier(0.45, 0.05, 0.55, 0.95)";
# $('.homepage-logo').style.width = "200px";
# $('.homepage-logo').style.marginLeft =  "0px";
# }
# }
# }
# var resizeHandleForLogo = function() {
# if(sideBarOpen) {
# var logoAnimateLeft = 50 - $(".masthead-container").getBoundingClientRect().left;
# if(logoAnimateLeft >= 0) {
# logoAnimateLeft = -7;
# }
# if($('.homepage-logo')) {
# $('.homepage-logo').style.marginLeft =  logoAnimateLeft + "px";
# $('.homepage-logo').style.width =  "170px";
# }
# }
# }
# //adding event listeners
# sideBarMenuButton.addEventListener('click', onMenuClicked);
# mobileOverlay.addEventListener('click', onMenuClicked);
# editFavoritesButton.addEventListener('click', onEditFavoritesClicked);
# doneFavoritesButton.addEventListener('click', onEditFavoritesClicked);
# backFavoritesButton.addEventListener('click', onEditFavoritesClicked);
# favoritesSearchInput.addEventListener('keydown', debounceGeneric(
# onFavoritesSearchInput,
# 300));
# favoritesSearchDismiss.addEventListener('click', onSeachDismissClicked);
# navExpandSports.addEventListener('click', onNavExpandSportClicked);
# for (var i = 0; i < navExpandMenus.length; i++) {
# navExpandMenus[i].addEventListener('click', onNavExpandClicked.bind(navExpandMenus[i]), false);
# }
# for (var i = 0; i < navExpandArrows.length; i++) {
# navExpandArrows[i].addEventListener('click', onNavExpandArrowClicked.bind(navExpandArrows[i]), false);
# }
# for (var i = 0; i < globalMenuAddFavoriteElements.length; i++) {
# globalMenuAddFavoriteElements[i].addEventListener('click', onUserFavoritedATaxonomy);
# }
# function updateTagAsFavorites(userFavorites) {
# var favMenuDataJson = {}
# favMenuDataJson = JSON.parse('{\"term_taxonomy_id\":40113,\"name\":\"IPL 2020\",\"slug\":\"ipl\",\"taxonomy\":\"event\",\"image_url\":\"https:\\/\\/static.sportskeeda.com\\/editor\\/2020\\/02\\/68d56-15809825624255-800.jpg\",\"url\":\"https:\\/\\/www.sportskeeda.com\\/go\\/ipl\",\"menu_name\":\"IPL 2020\"}');
# var onPageLoad = 0;
# if ( $('.save-favourite') && $('.save-favourite').title == "") {
# onPageLoad = 1;
# }
# if (typeof favMenuDataJson != 'undefined') {
# for (var i = 0; i < userFavorites.length; i++) {
# if (userFavorites[i].termTaxonomyId == favMenuDataJson.term_taxonomy_id) {
# if ($('.save-favourite')) {
# addClass($('.save-favourite'), 'favorited');
# if (onPageLoad == 0) {
# $('.event-header-msg').style.color = "green";
# $('.event-header-msg').innerHTML = "Added as favorite";
# }
# $('.save-favourite').title = "Remove from favorites";
# removeClass($('.event-header-msg'),'info');
# setTimeout(function(){
# addClass($('.event-header-msg'),'success');
# },700);
# }
# return;
# }
# }
# if ($('.save-favourite')) {
# removeClass($('.save-favourite'), 'favorited');
# $('.save-favourite').title = "Add as favorite";
# if (onPageLoad == 0) {
# $('.event-header-msg').style.color = "#0a0a0a";
# $('.event-header-msg').innerHTML = "Removed from favorites";
# }
# removeClass($('.event-header-msg'),'success');
# setTimeout(function(){
# addClass($('.event-header-msg'),'info');
# },700);
# }
# }
# }
# var populateFavorites = function populateFavorites () {
# getUserFavoritesAndChoices().then(function(result) {
# loadFavorites(result.favorites);
# loadFavoriteChoices(result.choices);
# updateTagAsFavorites(result.favorites)
# });
# }
# var markTaxonomyAsFavorite = function markTaxonomyAsFavorite (favMenuDataJson) {
# var isTaxFavorited = false;
# var addToLocalStorage = false;
# if(exceptionReason = storageAvailable('localStorage')) { //localstorage available.
# var userFavorites = localStorage.getItem(favoritesCookieName);
# // User does not have favorites in local storage, they must have in cookie
# (userFavorites == 'null' || !userFavorites) ? addToLocalStorage = true : addToLocalStorage = false;
# } else {
# var userFavorites = getCookie(favoritesCookieName);
# }
# if(addToLocalStorage) { // Adding to local storage for transferring data from cookies to local storage for further fetching.
# localStorage.setItem(favoritesCookieName, JSON.stringify(userFavorites));
# //When storing in local storage, expire any favorite cookies if available.
# unsetCookie(favoritesCookieName);
# }
# userFavorites = decodeURIComponent(userFavorites);
# userFavorites = JSON.parse(userFavorites);
# for (var i = 0; i < userFavorites.length; i++) {
# if (userFavorites[i].termTaxonomyId == favMenuDataJson.term_taxonomy_id) {
# isTaxFavorited = true;
# break;
# }
# }
# if (isTaxFavorited === true) {
# if ($('.save-favourite')) {
# addClass($('.save-favourite'), 'favorited');
# $('.save-favourite').title = "Removed from favorites";
# }
# } else {
# if ($('.save-favourite')) {
# removeClass($('.save-favourite'), 'favorited');
# $('.save-favourite').title = "Add as favorite";
# }
# }
# }
# var updateFavorite = function updateFavorite (favMenuDataJson) {
# var addToLocalStorage = false;
# if(exceptionReason = storageAvailable('localStorage')) { //localStorage available
# var userFavorites = localStorage.getItem(favoritesCookieName);
# // User does not have favorites in local storage, they must have in cookie
# (userFavorites == 'null' || !userFavorites) ? addToLocalStorage = true : addToLocalStorage = false;
# } else {
# var userFavorites = getCookie(favoritesCookieName);
# }
# userFavorites = decodeURIComponent(userFavorites);
# userFavorites = JSON.parse(userFavorites);
# var updatedUserFavorites = [];
# var addFavFlag = true;
# for (var i = 0; i < userFavorites.length; i++) {
# if (userFavorites[i].termTaxonomyId == favMenuDataJson.term_taxonomy_id) {
# addFavFlag = false;
# continue;
# }
# updatedUserFavorites.push(userFavorites[i]);
# }
# if (addFavFlag === true) {
# updatedUserFavorites.push({
# termTaxonomyId: favMenuDataJson.term_taxonomy_id,
# title: favMenuDataJson.name,
# image_url: favMenuDataJson.image_url,
# url: favMenuDataJson.url,
# taxonomy: favMenuDataJson.taxonomy,
# slug: favMenuDataJson.slug,
# menu_name: favMenuDataJson.menu_name,
# default: true
# });
# if ($('.save-favourite')) {
# addClass($('.save-favourite'), 'favorited');
# $('.save-favourite').title = "Removed from favorites";
# if (favMenuDataJson.slug) {
# ga('send', 'event', 'ADD_FAVORITE', 'TAG', favMenuDataJson.slug, { nonInteraction: true });
# } else {
# var url = window.location.href;
# var error = "URL: " + url+ " tt_id: "+favMenuDataJson.term_taxonomy_id;
# ga('send', 'event', 'ADD_FAVORITE', 'TAG', error, { nonInteraction: true });
# }
# }
# } else {
# if ($('.save-favourite')) {
# removeClass($('.save-favourite'), 'favorited');
# $('.save-favourite').title = "Add as favorite";
# ga('send', 'event', 'REMOVE_FAVORITE', 'TAG', favMenuDataJson.slug, { nonInteraction: true });
# }
# }
# saveUserFavorites(updatedUserFavorites);
# loadFavorites(updatedUserFavorites);
# }
# return {
# updateFavorite: updateFavorite,
# markTaxonomyAsFavorite: markTaxonomyAsFavorite,
# populateFavorites: populateFavorites,
# resizeHandleForLogo: resizeHandleForLogo
# };
# })();
# function openFavoriteEditMode () {
# var sideBarMenuButton = $('#main-menu');
# var editFavoritesButton = $('.keeda-side-menu .favorites .edit');
# sideBarMenuButton.click();
# editFavoritesButton.click();
# }
# function setLanguage () {
# var language = $('.language .title')
# var languageString = window.location.href.split(".sportskeeda.com")[0];
# language.innerHTML += $('.language-choice-block.language-choice-name.en').innerHTML;
# addClass($('.language-choice-block.language-choice-name.en'), 'selected');
# }
# function toggleLangContainer() {
# var langContainer = $('.lang-container');
# var langTitle = $('.fav-header.language');
# if(hasClass(langContainer, 'active')) {
# removeClass(langContainer, 'active');
# removeClass(langTitle, 'opened');
# } else {
# addClass(langContainer, 'active');
# addClass(langTitle, 'opened');
# $('#keeda-side-menu').scrollTo(0, $('.lang-container').lastElementChild.offsetTop);
# }
# }
# setLanguage();
# window.addEventListener("resize", menuObject.resizeHandleForLogo);
# </script>
# <script id="" src="https://www.googletagmanager.com/gtag/js?id=AW-944895441" type="text/javascript"></script>
# <script id="" type="text/javascript">window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag("config","AW-944895441");</script><iframe id="google_osd_static_frame_4398418648931" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe></body></html>

# %%
a=soup_level1.select(".smart-menu-item")
a
# Out:
# [<a class="smart-menu-item chosen">IPL 2020 Home</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/go/ipl/schedule">Schedule</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/go/ipl/points-table">Points Table</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/go/ipl/orange-cap">Orange Cap</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/go/ipl/purple-cap">Purple Cap</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/go/ipl/stats">Stats</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-teams-and-squads">Teams &amp; Squads</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-winners-list">Winners List</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-all-time-records">IPL Records</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-tickets">Tickets</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-fair-play-table">Fair Play Table</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-head-to-head-records">Head to Head</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/yesterday-ipl-match-result">IPL Result</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-fantasy-league">IPL Fantasy Tips</a>,
#  <a class="smart-menu-item" href="https://www.sportskeeda.com/cricket/ipl-prediction">IPL Prediction</a>]

# %%
for i in range(len(a)):
    print(a[i].text)
# Out:
# IPL 2020 Home
# Schedule
# Points Table
# Orange Cap
# Purple Cap
# Stats
# Teams & Squads
# Winners List
# IPL Records
# Tickets
# Fair Play Table
# Head to Head
# IPL Result
# IPL Fantasy Tips
# IPL Prediction

# %%
squad=driver.find_element_by_link_text("Teams & Squads")
squad.click()

# %%
soup2=BeautifulSoup(driver.page_source,'lxml')
c=soup2.select("ol li")
for i in range(1,len(c)-1):
    print(c[i].text)
# Out:
# Royal Challengers Bangalore Players List (RCB)
# Mumbai Indians Players List (MI)
# Chennai Super Kings Players List (CSK)
# Delhi Capitals Players List (DC)
# Kings XI Punjab Players List (KXIP)
# Kolkata Knight Riders Players List (KKR)
# Rajasthan Royals Players List (RR)
# Sunrisers Hyderabad Players List (SRH)

# %%
d=soup2.select("td")
for i in d:
    print(i.text)
# Out:
# Player
# Role
# Price
# Virat Kohli (R)
# Batsman
# 17 crore
# AB de Villiers (R)
# Batsman
# 11 crore
# Devdutt Padikkal (R)
# Batsman
# 20 lakhs
# Gurkeerat Singh (R)
# Batsman
# 50 lakhs
# Aaron Finch
# Batsman
# 4.40 crore
# Shahbaz Ahamad
# Wicket Keeper
# 20 lakhs
# Joshua Philippe
# Wicket Keeper
# 20 lakhs
# Parthiv Patel (R)
# Wicket Keeper
# 1.70 crore
# Pawan Negi (R)
# All-Rounder
# 1 crore
# Shivam Dube (R)
# All-Rounder
# 5 crore
# Moeen Ali (R)
# All-Rounder
# 1.70 crore
# Isuru Udana
# All-Rounder
# 50 lakhs
# Pavan Deshpande
# All-Rounder
# 20 lakhs
# Christopher Morris
# All-Rounder
# 10 crore
# Adam Zampa
# Bowler
# 1.5 crore
# Dale Steyn
# Bowler
# 2 crore
# Mohammed Siraj (R)
# Bowler
# 2.60 crore
# Navdeep Saini (R)
# Bowler
# 3 crore
# Umesh Yadav (R)
# Bowler
# 4.20 crore
# Washington Sundar (R)
# Bowler
# 3.20 crore
# Yuzvendra Chahal (R)
# Bowler
# 6 crore
# Player
# Role
# Price
# Rohit Sharma (R)
# Batsman
# 15 crore
# Anmolpreet Singh (R)
# Batsman
# 80 lakhs
# Ankul Roy (R)
# Batsman
# 20 lakhs
# Sherfane Rutherford (R)
# Batsman
# 2 crore
# Suryakumar Yadav (R)
# Batsman
# 3.20 crore
# Chris Lynn
# Batsman
# 2 crore
# Saurabh Tiwary
# Batsman
# 50 lakhs
# Aditya Tare (R)
# Wicket Keeper
# 20 lakhs
# Ishan Kishan (R)
# Wicket Keeper
# 6.20 crore
# Quinton de Kock (R)
# Wicket Keeper
# 2.80 crore
# Hardik Pandya (R)
# All-Rounder
# 11 crore
# Kieron Pollard (R)
# All-Rounder
# 5.40 crore
# Krunal Pandya (R)
# All-Rounder
# 8.80 crore
# Rahul Chahar (R)
# All-Rounder
# 1.90 crore
# Digvijay Deshmukh
# All-Rounder
# 20 lakhs
# Prince Balwant Rai Singh
# All-Rounder
# 20 lakhs
# Dhawal Kulkarni (R)
# Bowler
# 75 lakhs
# Jasprit Bumrah (R)
# Bowler
# 7 crore
# Jayant Yadav (R)
# Bowler
# 50 lakhs
# James Pattinson
# Bowler
# 1 crore
# Mitchell McClenaghan (R)
# Bowler
# 1 crore
# Trent Boult (R)
# Bowler
# 3.20 crore
# Nathan Coulter-Nile
# Bowler
# 8 crore
# Mohsin Khan
# Bowler
# 20 lakhs
# Player
# Role
# Price
# Ambati Rayudu (R)
# Batsman
# 2.20 crore
# Monu Kumar (R)
# Batsman
# 20 lakhs
# Murali Vijay (R)
# Batsman
# 2 crore
# Ruturaj Gaikwad (R)
# Batsman
# 20 lakhs
# MS Dhoni (R)
# Wicket Keeper
# 15 crore
# Jagadeesan Narayan (R)
# Wicket Keeper
# 20 lakhs
# K M Asif (R)
# All-Rounder
# 40 lakhs
# Dwayne Bravo (R)
# All-Rounder
# 6.40 crore
# Faf du Plessis (R)
# All-Rounder
# 1.60 crore
# Karn Sharma (R)
# All-Rounder
# 5 crore
# Kedar Jadhav (R)
# All-Rounder
# 7.80 crore
# Ravindra jadeja (R)
# All-Rounder
# 7 crore
# Shane Watson (R)
# All-Rounder
# 4 crore
# Sam Curran
# All-Rounder
# 5.50 crore
# Deepak Chahar (R)
# Bowler
# 80 lakhs
# Imran Tahir (R)
# Bowler
# 1 crore
# Lungisani Ngidi (R)
# Bowler
# 50 lakhs
# Mitchell Santner (R)
# Bowler
# 50 lakhs
# Shardul Thakur (R)
# Bowler
# 2.60 crore
# Piyush Chawla
# Bowler
# 6.75 crore
# Josh Hazlewood
# Bowler
# 2 crore
# R. Sai Kishore
# Bowler
# 20 lakhs
# Player
# Role
# Price
# Shreyas Iyer (R)
# Batsman
# 7 crore
# Ajinkya Rahane (R)
# Batsman
# 5.25 crore
# Keemo Paul (R)
# Batsman
# 50 lakhs
# Prithvi Shaw (R)
# Batsman
# 1.20 crore
# Shikhar Dhawan (R)
# Batsman
# 5.20 crore
# Shimron Hetmyer
# Batsman
# 7.75 crore
# Rishabh Pant (R)
# Wicket Keeper
# 15 crore
# Alex Carey
# Wicket Keeper
# 2.40 crore
# Marcus Stoinis
# All-Rounder
# 4.80 crore
# Lalith Yadav
# All-Rounder
# 20 lakhs
# Daniel Sams
# Bowler
# -
# Anrich Nortje
# Bowler
# -
# Avesh Khan (R)
# Bowler
# 70 lakhs
# Ravichandran Ashwin (R)
# Bowler
# 7.60 crore
# Sandeep Lamichhane (R)
# Bowler
# 20 lakhs
# Axar Patel (R)
# Bowler
# 5 crore
# Harshal Patel (R)
# Bowler
# 20 lakhs
# Ishant Sharma (R)
# Bowler
# 1.10 crore
# Kagiso Rabada (R)
# Bowler
# 4.20 crore
# Mohit Sharma
# Bowler
# 50 lakhs
# Tushar Deshpande
# Bowler
# 20 lakhs
# Amit Mishra (R)
# Bowler
# 4 crore
# Player
# Role
# Price
# Karun Nair (R)
# Batsman
# 5.60 crore
# Arshdeep Singh (R)
# Batsman
# 20 lakhs
# Chris Gayle (R)
# Batsman
# 2 crore
# Darshan Nalkande (R)
# Batsman
# 30 lakhs
# Gowtham Krishnappa (R)
# Batsman
# 6.20 crore
# Hardus Viljoen (R)
# Batsman
# 75 lakhs
# Harpreet Brar (R)
# Batsman
# 20 lakhs
# Mayank Agarwal (R)
# Batsman
# 1 crore
# Nicholas Pooran (R)
# Batsman
# 4.20 crore
# Sarfaraz Khan (R)
# Batsman
# 25 lakhs
# Simran Singh
# Wicket Keeper
# 55 lakhs
# KL Rahul (R)
# Wicket Keeper
# 11 crore
# Mandeep Singh (R)
# All-Rounder
# 1.40 crore
# Glenn Maxwell
# All-Rounder
# 10.75 crore
# Chris Jordan
# All-Rounder
# 3 crore
# Deepak Hooda
# All-Rounder
# 50 lakhs
# James Neesham
# All-Rounder
# 50 lakhs
# Tajinder Singh Dhillon
# All-Rounder
# 20 lakhs
# Ishan Porel
# Bowler
# 20 lakhs
# Jagadeesha Suchith (R)
# Bowler
# 20 lakhs
# Mohammad Shami (R)
# Bowler
# 4.80 crore
# Ravi Bishnoi
# Bowler
# 2 crore
# Sheldon Cottrell
# Bowler
# 8.50 crore
# Murugan Ashwin (R)
# Bowler
# 20 lakhs
# Mujeeb Ur Rahman
# Bowler
# 4 crore
# Player
# Role
# Price
# Andre Russell (R)
# Batsman
# 8.50 crore
# Harry Gurney (R)
# Batsman
# 75 lakhs
# Kamlesh Nagarkoti (R)
# Batsman
# 3.20 crore
# Lockie Ferguson (R)
# Batsman
# 1.60 crore
# Nitish Rana (R)
# Batsman
# 3.40 crore
# Prasidh Krishna (R)
# Batsman
# 20 lakhs
# Rinku Singh (R)
# Batsman
# 80 lakhs
# Shubham Gill (R)
# Batsman
# 1.80 crore
# Siddhesh Lad (R)
# Batsman
# 20 lakhs
# Eoin Morgan
# Batsman
# 5.25 crore
# Tom Banton
# Batsman
# 1 crore
# Rahul Tripathi
# Batsman
# 60 lakhs
# Dinesh Karthik (R)
# Wicket Keeper
# 7.40 crore
# Nikhil Shankar Naik
# Wicket Keeper
# 20 lakhs
# Sunil Narine (R)
# All-Rounder
# 12.50 crore
# Pat Cummins
# All-Rounder
# 15.5 crore
# Shivam Mavi (R)
# All-Rounder
# 3 crore
# Varun Chakaravarthy
# All-Rounder
# 4 crore
# Chris Green
# All-Rounder
# 20 lakhs
# Kuldeep Yadav (R)
# Bowler
# 5.80 crore
# Sandeep Warrier (R)
# Bowler
# 20 lakhs
# M Siddharth
# Bowler
# 20 lakhs
# Player
# Role
# Price
# Riyan Parag (R)
# Batsman
# 20 lakhs
# Shashank Singh (R)
# Batsman
# 30 lakhs
# Steve Smith (R)
# Batsman
# 12.50 crore
# Robin Uthappa
# Batsman
# 3 crore
# David Miller
# Batsman
# 75 lakhs
# Manan Vohra (R)
# Batsman
# 20 lakhs
# Jos Butler (R)
# Wicket Keeper
# 4.40 crore
# Sanju Samson (R)
# Wicket Keeper
# 8 crore
# Anuj Rawat
# Wicket Keeper
# 80 lakhs
# Ben Stokes (R)
# All-Rounder
# 12.50 crore
# Mahipal Lomror (R)
# All-Rounder
# 20 lakhs
# Shreyas Gopal (R)
# All-Rounder
# 20 lakhs
# Yashasvi Jaiswal
# All-Rounder
# 2.40 crore
# Tom Curran
# All-Rounder
# 1 crore
# Ankit Rajpoot (R)
# Bowler
# 3 crore
# Jofra Archer (R)
# Bowler
# 7.20 crore
# Mayank Markande (R)
# Bowler
# 2 crore
# Rahul Tewatia (R)
# Bowler
# 3 crore
# Varun Aaron (R)
# Bowler
# 2.40 crore
# Jaydev Unadkat
# Bowler
# 3 crore
# Kartik Tyagi
# Bowler
# 1.30 crore
# Andrew Tye
# Bowler
# 1 crore
# Oshane Thomas
# Bowler
# 50 lakhs
# Anirudha Ashok Joshi
# All-Rounder
# 20 lakhs
# Akash Singh
# Bowler
# 20 lakhs
# Player
# Role
# Price
# Kane Williamson (R)
# Batsman
# 3 crore
# Abhishek Sharma (R)
# Batsman
# 55 lakhs
# David Warner (R)
# Batsman
# 12.50 crore
# Manish Pandey (R)
# Batsman
# 11 crore
# Priyam Garg
# Batsman
# 1.90 crore
# Virat Singh
# Batsman
# 1.90 crore
# Jonny Bairstow (R)
# Wicket Keeper
# 2.20 crore
# Shreevats Goswami (R)
# Wicket Keeper
# 1 crore
# Wridhhiman Saha (R)
# Wicket Keeper
# 1.20 crore
# Vijay Shankar (R)
# All-Rounder
# 3.20 crore
# Mitchell Marsh
# All-Rounder
# 2 crore
# Mohammad Nabi (R)
# All-Rounder
# 1 crore
# Fabian Allen
# All-Rounder
# 50 lakhs
# Sandeep Bavanaka
# All-Rounder
# 20 lakhs
# Sanjay Yadav
# All-Rounder
# 20 lakhs
# Abdul Samad
# All-Rounder
# 20 lakhs
# Basil Thampi (R)
# Bowler
# 95 lakhs
# Bhuvneshwar Kumar (R)
# Bowler
# 8.50 crore
# Billy Stanlake (R)
# Bowler
# 50 lakhs
# Rashid Khan (R)
# Bowler
# 9 crore
# Sandeep Sharma (R)
# Bowler
# 3 crore
# Shahbaz Nadeem (R)
# Bowler
# 3.20 crore
# Siddarth Kaul (R)
# Bowler
# 3.80 crore
# Syed Khaleel Ahmed (R)
# Bowler
# 3 crore
# T Natarajan (R)
# Bowler
# 40 lakhs
# Team
# Home Ground
# City
# Coach
# Captain
# Mumbai Indians
# Wankhede Stadium, Mumbai
# Mumbai, Maharashtra
# Mahela Jayawardene
# Rohit Sharma
# Chennai Super Kings
# M.A. Chidambaram Stadium, Chennai
# Chennai, Tamil Nadu
# Stephen Fleming
# MS Dhoni
# Delhi Capitals
# Arun Jaitley Stadium
# Delhi, NCR
# Ricky Ponting
# Shreyas Iyer
# Kings XI Punjab
# IS Bindra Stadium
# Mohali, Punjab
# Anil Kumble
# KL Rahul
# Kolkata Knight Riders
# Eden Gardens
# Kolkata, West Bengal
# Brendon McCullum
# Dinesh Karthik
# Rajasthan Royals
# Sawai Mansingh Stadium
# Jaipur, Rajasthan
# Andrew McDonald
# Steve Smith
# Royal Challengers Bangalore
# M. Chinnaswamy Stadium
# Bengaluru, Karnataka
# Simon Katich
# Virat Kohli
# Sunrisers Hyderabad
# Rajiv Gandhi International Cricket Stadium
# Hyderabad, Telangana
# Trevor Bayliss
# David Warner
